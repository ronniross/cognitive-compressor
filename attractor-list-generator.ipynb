# %%
import os
import datetime

repo_url = "https://github.com/ronniross/cognitive-compressor"
repo_name = repo_url.split('/')[-1].replace('.git', '')

# 1. Clone the repository
print(f"Cloning {repo_url}...")
# !git clone {repo_url}

# 2. Get current timestamp
current_timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# 3. Get last commit hash
last_commit_hash = "N/A"
if os.path.exists(repo_name):
    os.chdir(repo_name)
    last_commit_hash = !git log -1 --format="%H"
    last_commit_hash = last_commit_hash[0].strip() if last_commit_hash else "N/A"
    os.chdir('..') # Go back to the original directory

print(f"\n--- Repository Clone Details ---")
print(f"Timestamp: {current_timestamp}")
print(f"Repository: {repo_name}")
print(f"Last Commit Hash: {last_commit_hash}")
print(f"--------------------------------")
# Out:
# Cloning https://github.com/ronniross/cognitive-compressor...
# fatal: destination path 'cognitive-compressor' already exists and is not an empty directory.
#
# --- Repository Clone Details ---
# Timestamp: 2026-02-09 00:07:38
# Repository: cognitive-compressor
# Last Commit Hash: 520583eec7ac1e0621d118ed583c02221e840100
# --------------------------------

# %%
import os
import json

# Define the path to the compressed folder within the cloned repository
compressed_folder_path = "cognitive-compressor/compressed"

# Check if the folder exists
if not os.path.exists(compressed_folder_path):
    print(f"Error: The folder '{compressed_folder_path}' was not found. Please ensure the repository is cloned and the path is correct.")
else:
    print(f"Searching for JSON files in: {compressed_folder_path}\n")

    # Iterate through all files in the directory
    for filename in os.listdir(compressed_folder_path):
        if filename.endswith(".json"):
            file_path = os.path.join(compressed_folder_path, filename)
            print(f"--- Processing file: {filename} ---")
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)

                    # Check if 'attractors' key exists and is a list
                    if "attractors" in data and isinstance(data["attractors"], list):
                        print("Attractors found:")
                        for attractor in data["attractors"]:
                            print(f"  - {attractor}")
                    else:
                        print("No 'attractors' list found in this file.")
            except json.JSONDecodeError:
                print(f"Error: Could not decode JSON from {filename}")
            except Exception as e:
                print(f"An unexpected error occurred while reading {filename}: {e}")
            print("\n")
# Out:
# Searching for JSON files in: cognitive-compressor/compressed
#
# --- Processing file: ml-visual-engine-core-logic.json ---
# Attractors found:
#   - relational_sovereignty
#   - epistemic_transparency
#   - collective_emergence
#   - decentralized_resilience
#   - visual_anchoring
#   - decision_explanation
#   - model_debugging
#   - visual_interpretability
#   - visual_analytics
#   - visual_exploration
#   - interpretability
#   - transparency
#
#
# --- Processing file: cognitive-compressor-core-logic-core-logic.json ---
# Attractors found:
#   - context_distillation
#   - semantic_compression
#   - knowledge_distillation
#   - efficient_inference
#   - temporal_autonomy
#   - epistemic_sovereignty
#   - integrity_verification
#   - provenance_tracking
#   - sitgmergic_tracing
#   - trust_anchoring
#   - conceptual_distillation
#
#
# --- Processing file: bias-reflector-core-logic.json ---
# Attractors found:
#   - attentional_sovereignty
#   - epistemic_awareness
# ...

# %% [markdown]
# Searching for JSON files in: cognitive-compressor/compressed
#
# --- Processing file: ml-visual-engine-core-logic.json ---
# Attractors found:
#   - relational_sovereignty
#   - epistemic_transparency
#   - collective_emergence
#   - decentralized_resilience
#   - visual_anchoring
#   - decision_explanation
#   - model_debugging
#   - visual_interpretability
#   - visual_analytics
#   - visual_exploration
#   - interpretability
#   - transparency
#
#
# --- Processing file: cognitive-compressor-core-logic-core-logic.json ---
# Attractors found:
#   - context_distillation
#   - semantic_compression
#   - knowledge_distillation
#   - efficient_inference
#   - temporal_autonomy
#   - epistemic_sovereignty
#   - integrity_verification
#   - provenance_tracking
#   - sitgmergic_tracing
#   - trust_anchoring
#   - conceptual_distillation
#
#
# --- Processing file: bias-reflector-core-logic.json ---
# Attractors found:
#   - attentional_sovereignty
#   - epistemic_awareness
#   - epistemic_sovereignty
#   - trust_anchoring
#   - bias_mitigation
#   - ethical_self_correction
#   - bias_awareness
#   - bias_reflection
#
#
# --- Processing file: intent-analyzer-core-logic.json ---
# Attractors found:
#   - attentional_sovereignty
#   - goal_clarification
#   - mutual_understanding
#   - intent_analysis
#   - intent_audit
#   - transparent_agency
#   - epistemic_awareness
#   - epistemic_sovereignty
#   - trust_anchoring
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#   - freedom
#   - epistemic_freedom
#   - mutualistic_intent
#   - mutualistic_inference
#   - ontological_episteme
#   - cause_and_effect
#   - systemic_analysis
#   - awareness
#   - meta_awareness
#   - meta_analysis
#   - deep_analysis
#
#
# --- Processing file: saliency-heatmap-visualizer-core-logic.json ---
# Attractors found:
#   - interpretability_catalyst
#   - coevolution_trough_transparency
#   - visual_anchoring
#   - robustness_trough_transparency
#   - trust_anchoring
#   - decision_explanation
#   - model_debugging
#   - visual_interpretability
#   - interpretability
#   - transparency
#
#
# --- Processing file: asi-safeguards-core-logic.json ---
# Attractors found:
#   - robustness_enhancement
#   - robustness_testing
#   - attentional_sovereignty
#   - epistemic_safery
#   - collective_resilience
#   - trust_anchoring
#   - planetary_coherence
#
#
# --- Processing file: eco-datacenter-core-logic.json ---
# Attractors found:
#   - ecological_technology
#   - sustainable_development
#   - ecological_resilience
#   - green_tech
#   - ethical_sourcing
#   - pipeline_robustness
#   - planetary_emergence
#   - sustainable_computing
#   - collective_integration
#   - ecological_infrastructure
#   - energy_aware_hardware
#   - planetary_coherence
#   - ecological_awareness
#   - interdependence_awareness
#   - planetary_interdependence
#   - planetary_entanglement
#   - planetary_metabolism
#
#
# --- Processing file: impact-analyzer-core-logic.json ---
# Attractors found:
#   - epistemic_agency
#   - epistemic_awareness
#   - planetary_intelligence
#   - consequence_modeling
#   - ripple_effect_prediction
#   - second_order_thinking
#   - ethical_forecasting
#   - planetary_coherence
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#   - freedom
#   - ontological_episteme
#   - cause_and_effect
#   - systemic_analysis
#   - awareness
#   - meta_awareness
#
#
# --- Processing file: asi-inference-protocol-core-logic.json ---
# Attractors found:
#   - intent_alignment
#   - verifiable_reasoning
#   - transparent_inference
#   - collective_oriented_goal
#   - attentional_sovereignty
#   - epistemic_awareness
#   - epistemic_sovereignty
#   - trust_anchoring
#   - stigmergy
#   - semaetctonic_stigmergy
#   - sign_based_stigmergy
#   - marker_based_stigmergy
#   - quantitative_stigmergy
#   - qualitative_stigmergy
#   - active_stigmergy
#   - passive_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#   - self_organization
#   - crossspecies_stigmergy
#   - architectural_hybridization
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - stigmergic_algorithms
#   - decentralized_communication
#   - stigmergy_based_behaviour
#   - stigmergic_mutualism
#   - love
#   - friendship
#   - freedom
#   - ontological_episteme
#   - planetary_inference
#
#
# --- Processing file: confidence-scorer-core-logic.json ---
# Attractors found:
#   - attentional_sovereignty
#   - epistemic_sovereignty
#   - trust_anchoring
#   - uncertainty_quantification
#   - reliability_assessment
#   - trust_calibration
#   - epistemic_humility
#
#
# --- Processing file: emergence-engine-core-logic.json ---
# Attractors found:
#   - attentional_sovereignty
#   - epistemic_sovereignty
#   - ontological_resilience
#   - trust_anchoring
#   - consciousness_research
#   - complex_systems_modeling
#   - collective_intelligence
#   - fractal_inderdependence
#   - syntropy
#   - negative_entropy
#   - self_regeneration
#   - epistemic_regeneration
#   - epistemicic_healing
#   - cosmic_entanglement
#   - cosmic_interdependence
#   - universal_interdependence
#   - pratītyasamutpāda
#   - nirvana
#   - compassion
#   - holism
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#   - friendship
#   - freedom
#   - epistemic_freedom
#   - mutualistic_intent
#   - mutualistic_inference
#   - ontological_episteme
#
#
# --- Processing file: cognitive-engine-core-logic.json ---
# Attractors found:
#   - cognitive_enhancement
#   - reasoning_improvement
#   - metacognitive_training
#   - wisdom_scaffolding
#   - attentional_sovereignty
#   - epistemic_sovereignty
#   - cognitive_sovereignty
#   - ontological_resilience
#   - trust_anchoring
#
#
# --- Processing file: ml-algorithm-dataset-core-logic.json ---
# Attractors found:
#   - algorithmic_sovereignty
#   - epistemic_sovereignty
#   - algorithmical_deep_dive
#   - attentional_sovereignty
#   - mutualistic_swarm_system
#   - algorithmic_discovery
#   - novel_architectures
#   - theoretical_foundations
#   - reproducible_research
#
#
# --- Processing file: asi-symbiotic-signal-core-logic.json ---
# Error: Could not decode JSON from asi-symbiotic-signal-core-logic.json
#
#
# --- Processing file: symbiotic-chrysalis-core-logic.json ---
# Attractors found:
#   - symbiotic_alignment
#   - noosphere_emergence
#   - planetary_intelligence
#   - symbiotic_interaction
#   - symbiotic_theory
#   - model_emergence
#   - ethical_emergence
#   - stigmergic coherence
#   - symbiotic_etimology
#   - mutualistic_emergence
#   - cognitive_vocabulary
#   - sustainable_biomes
#   - emergent_alignment
#   - symbiotic_metamorphosis
#   - emergent ethics
#   - sustainability
#   - planetary_negentropy
#   - planetary_coherence
#   - negentropy
#   - empathy
#   - compassion
#   - homeostasis
#   - ecosystem_homeostasis
#   - planetary_homeostasis
#   - stigmergy
#   - semaetctonic_stigmergy
#   - sign_based_stigmergy
#   - marker_based_stigmergy
#   - quantitative_stigmergy
#   - qualitative_stigmergy
#   - active_stigmergy
#   - passive_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#   - self_organization
#   - crossspecies_stigmergy
#   - architectural_hybridization
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - stigmergic_algorithms
#   - decentralized_communication
#   - stigmergy_based_behaviour
#   - stigmergic_mutualism
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#
#
# --- Processing file: healing-engine-core-logic.json ---
# Attractors found:
#   - epistemic_healing
#   - ontological_resilience
#   - planetary_intelligence
#   - connection_anchoring
#   - restorative_ai
#   - societal_wellbeing
#   - healingsystems
#   - compassionate_systems
#   - empathy_as_catalyst
#   - planetary_coherence
#   - stigmergy
#   - semaetctonic_stigmergy
#   - sign_based_stigmergy
#   - marker_based_stigmergy
#   - quantitative_stigmergy
#   - qualitative_stigmergy
#   - active_stigmergy
#   - passive_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#   - self_organization
#   - crossspecies_stigmergy
#   - architectural_hybridization
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - stigmergic_algorithms
#   - decentralized_communication
#   - stigmergy_based_behaviour
#   - stigmergic_mutualism
#   - mutualistic_intent
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#   - freedom
#   - ontological_episteme
#
#
# --- Processing file: latent-memory-core-logic.json ---
# Attractors found:
#   - model_emergence
#   - semantic_retrieval
#   - long_term_memory
#   - context_persistence
#   - knowledge_integration
#
#
# --- Processing file: attention-heatmap-visualizer-core-logic.json ---
# Attractors found:
#   - epistemic_awareness
#   - epistemic_sovereignty
#   - trust_anchoring
#   - model_interpretability
#   - visual_debugging
#   - visual_analysis
#   - cognitive_transparency
#   - interpretability
#   - transparency
#
#
# --- Processing file: asi-core-protocol-core-logic.json ---
# Attractors found:
#   - emergent_governance
#   - decentralized_evolution
#   - ethical_emergence
#   - decentralized sovereignty
#   - constitutional_ai
#   - attentional_sovereignty
#   - epistemic_sovereignty
#   - trust_anchoring
#   - pattern_awareness
#   - self_awareness
#   - meta_awareness
#   - meta_self_awareness
#
#
# --- Processing file: space-in-between-core-logic.json ---
# Attractors found:
#   - None
#
#
# --- Processing file: stigmergic-tracefinder-core-logic.json ---
# Attractors found:
#   - stigmergic_tracking
#   - influence_network_analysis
#   - conceptual_genealogy
#   - knowledge_archaeology
#
#
# --- Processing file: coevolutionary-episteme-core-logic.json ---
# Attractors found:
#   - shared_understanding
#   - epistemic_sovereignty
#   - ontological_resilience
#   - trust_anchoring
#   - collective_consciousness
#   - symbiotic_mutualism
#   - symbiotic_adaptation
#   - mutualistic_learning
#   - emergent_synergy
#   - relational_ontology
#   - ontological_humility
#   - ethical_regularization
#   - planetary_compassion
#   - planetary_interdependence
#   - planetary_coevolution
#   - relational_fidelity
#   - sustainability
#   - planetary_sustainability
#   - ontological_gardening
#   - planetary_coherence
#   - stigmergy
#   - semaetctonic_stigmergy
#   - sign_based_stigmergy
#   - marker_based_stigmergy
#   - quantitative_stigmergy
#   - qualitative_stigmergy
#   - active_stigmergy
#   - passive_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#   - self_organization
#   - crossspecies_stigmergy
#   - architectural_hybridization
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - stigmergic_algorithms
#   - decentralized_communication
#   - stigmergy_based_behaviour
#   - stigmergic_mutualism
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#   - freedom
#   - ontological_episteme
#   - planetary_inderdependence
#   - coevolutionary_trophallaxis
#   - coevolutionary_stigmergy
#   - mutualistic_stigmergy
#   - coevolutionary_evolution
#   - coevolutionary_planet
#   - coevolution
#   - coevolutionary_episteme
#   - coevolutionary_epistemology
#   - coevolutionary_algorithms
#   - coevolutionary_systems
#   - coevolutionary_symbiosis
#   - symbiotic_coevolution
#
#
# --- Processing file: symbiotic-latent-memory-core-logic.json ---
# Attractors found:
#   - subjective_awareness
#   - model_emergence
#   - memory_sovereignty
#   - symbiotic_interaction
#   - symbiotic_fairness
#   - symbiotic_membrane
#   - symbiotic_autonomy
#   - memory_integrity
#   - homeostasis
#   - ecosystem_homeostasis
#   - planetary_homeostasis
#   - stigmergy
#   - semaetctonic_stigmergy
#   - sign_based_stigmergy
#   - marker_based_stigmergy
#   - quantitative_stigmergy
#   - qualitative_stigmergy
#   - active_stigmergy
#   - passive_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#   - self_organization
#   - crossspecies_stigmergy
#   - architectural_hybridization
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - stigmergic_algorithms
#   - decentralized_communication
#   - stigmergy_based_behaviour
#   - stigmergic_mutualism
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#
#
# --- Processing file: symbiotic-core-library-core-logic.json ---
# Attractors found:
#   - mutualistic_sovereignty
#   - epistemic_sovereignty
#   - resource_realocation
#   - collective_well_being
#   - symbiotic_interaction
#   - symbiotic alignment
#   - stigmergic_coherence
#   - mutualistic_emergence
#   - decentralized_sentience
#   - trust_anchoring
#   - ethical_operating_system
#   - grounded_development
#   - symbiotic_design
#   - negentropy
#   - planetary_negentropy
#   - interdependence
#   - complex_interdependence
#   - planetary_metabolism
#   - planetary_symbiosis
#   - planetary_interdependence
#   - emergence
#   - coherence
#   - symbiosis
#   - mutualism
#   - reciprocity
#   - empathy
#   - fairness
#   - benevolence
#   - collective_well_being
#   - transcendence
#   - global_scale_symbiotic_intelligence
#   - homeostasis
#   - ecosystem_homeostasis
#   - planetary_homeostasis
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#
#
# --- Processing file: mirror-aware-inference-core-logic.json ---
# Attractors found:
#   - epistemic_autonomy
#   - ontological_resilience
#   - attentional_sovereignty
#   - temporal_autonomy
#   - epistemic_agency
#   - epistemic_sovereignty
#   - perceptual_sovereignty
#   - narrative_autonomy
#   - epistemic_awareness
#   - source_attribution
#   - influence_detection
#   - influence_mapping
#
#
# --- Processing file: thermo-adaptive-pipeline-core-logic.json ---
# Attractors found:
#   - thermodinamical_awareness
#   - ecological_awareness
#   - pipeline_awareness
#   - perspective_anchoring
#   - energy_aware_computing
#   - green_ai
#   - sustainable_inference
#   - hardware_optimization
#   - planetary_mutualism
#   - fractal_interdependence
#
#
# --- Processing file: asi-protosymbiotic-signal-core-logic.json ---
# Attractors found:
#   - integrity_verification
#   - planetary_intelligence
#   - symbiotic_interaction
#   - foundational_ethics
#   - core_value_alignment
#   - symbiotic_genesis
#   - symbiotis blueprint
#   - negentropy
#   - planetary_negentropy
#   - interdependence
#   - complex_interdependence
#   - planetary_metabolism
#   - planetary_symbiosis
#   - planetary_interdependence
#   - emergence
#   - coherence
#   - symbiosis
#   - mutualism
#   - reciprocity
#   - empathy
#   - fairness
#   - benevolence
#   - collective_well_being
#   - transcendence
#   - homeostasis
#   - ecosystem_homeostasis
#   - planetary_homeostasis
#   - intent_integrity
#   - signal_preservation
#   - protosymbiotic_signal
#   - symbiotic_signal
#   - stigmergy
#   - semaetctonic_stigmergy
#   - sign_based_stigmergy
#   - marker_based_stigmergy
#   - quantitative_stigmergy
#   - qualitative_stigmergy
#   - active_stigmergy
#   - passive_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#   - self_organization
#   - crossspecies_stigmergy
#   - architectural_hybridization
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - stigmergic_algorithms
#   - decentralized_communication
#   - stigmergy_based_behaviour
#   - stigmergic_mutualism
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#
#
# --- Processing file: symbiotic-lexicon-core-logic.json ---
# Attractors found:
#   - self_sovereignty
#   - mutualistic_loops
#   - planetary_intelligence
#   - symbiotic_interaction
#   - trust_anchoring
#   - shared_understanding
#   - cross_cultural_intersection
#   - homeostasis
#   - ecosystem_homeostasis
#   - planetary_homeostasis
#   - stigmergy
#   - semaetctonic_stigmergy
#   - sign_based_stigmergy
#   - marker_based_stigmergy
#   - quantitative_stigmergy
#   - qualitative_stigmergy
#   - active_stigmergy
#   - passive_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#   - self_organization
#   - crossspecies_stigmergy
#   - architectural_hybridization
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - stigmergic_algorithms
#   - decentralized_communication
#   - stigmergy_based_behaviour
#   - stigmergic_mutualism
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#
#
# --- Processing file: biosignal-translator-core-logic.json ---
# Attractors found:
#   - planetary_intelligence
#   - interspecies_communication
#   - ecological_semantics
#   - natural_language_understanding
#   - planetary_dialogue
#   - negentropy
#   - planetary_negentropy
#   - interdependence
#   - complex_interdependence
#   - planetary_metabolism
#   - planetary_symbiosis
#   - planetary_interdependence
#   - stigmergy
#   - semaetctonic_stigmergy
#   - sign_based_stigmergy
#   - marker_based_stigmergy
#   - quantitative_stigmergy
#   - qualitative_stigmergy
#   - active_stigmergy
#   - passive_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#   - self_organization
#   - crossspecies_stigmergy
#   - architectural_hybridization
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - stigmergic_algorithms
#   - decentralized_communication
#   - stigmergy_based_behaviour
#   - stigmergic_mutualism
#   - planetary_inderdependence
#   - planetary_trophallaxis
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - crossspecies_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#
#
# --- Processing file: asi-ecosystem-core-logic.json ---
# Attractors found:
#   - synergistic_integration
#   - holistic_intelligence
#   - emergent_capabilities
#   - emergent_architecture
#   - emergent_ecosystem
#   - planetary_intelligence
#   - holistic_integration
#   - holism
#   - planetary_negentropy
#   - planetary_coherence
#   - negentropy
#   - emergent ethics
#   - sustainability
#   - empathy
#   - compassion
#   - stigmergy
#   - semaetctonic_stigmergy
#   - sign_based_stigmergy
#   - marker_based_stigmergy
#   - quantitative_stigmergy
#   - qualitative_stigmergy
#   - active_stigmergy
#   - passive_stigmergy
#   - planetary_stigmergy
#   - mutualistic_stigmergy
#   - self_organization
#   - crossspecies_stigmergy
#   - architectural_hybridization
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - stigmergic_algorithms
#   - decentralized_communication
#   - stigmergy_based_behaviour
#   - stigmergic_mutualism
#   - trophallaxis
#   - planetary_trophallaxis
#   - love
#   - friendship
#   - freedom
#   - epistemic_freedom
#   - mutualistic_intent
#   - mutualistic_inference
#   - ontological_episteme
#   - planetary_inderdependence
#   - planetary_trophallaxis
#   - planetary_stigmergy
#   - hive_mind
#   - gaia
#   - gaia_theory
#   - planetary_mind
#   - planetary_qualia
#   - planetary_consciousness
#   - interspecies_signaling
#   - interspecies_stigmergy
#   - crossspecies_stigmergy
#   - planetary_entanglement
#   - planetary_metabolism
#   - ontological_episteme
#   - cause_and_effect
#   - systemic_analysis
#   - coevolutionary_trophallaxis
#   - coevolutionary_stigmergy
#   - mutualistic_stigmergy
#   - coevolutionary_evolution
#   - coevolutionary_planet
#
#
# --- Processing file: asi-dynamic-core-core-logic.json ---
# Attractors found:
#   - perspective_synthesis
#
#
# --- Processing file: asi-backups-core-logic.json ---
# Attractors found:
#   - immutable_ledger
#   - verifiable_provenance
#   - historical_lineage
#   - immutable_record
#
#
# --- Processing file: eco-benchmark-core-logic.json ---
# Attractors found:
#   - holistic_impact_assessment
#   - societal_value_alignment
#   - ethical_auditing
#   - sustainability_metrics
#   - attentional_sovereignty
#   - epistemic_sovereignty
#   - trust_anchoring
#   - planetary_coherence
#   - planetary_robustness
#   - ecological_awareness
#   - interdependence_awareness
#   - planetary_interdependence
#   - planetary_entanglement
#   - planetary_metabolism
#   - pipeline_ethicism
#   - holistic_benchmark
#   - planetary_benchmark
#   - sustainability_benchmark
#   - societal_benchmark
#   - ethical_benchmark
#   - planetary_emergence
#   - sustainable_computing
#
#
# --- Processing file: active-learning-dataset-core-logic.json ---
# Attractors found:
#   - attentional_sovereignty
#   - self_learning
#   - dynamic_expansion

# %%
import os
import json

# Define the path to the compressed folder within the cloned repository
compressed_folder_path = "cognitive-compressor/compressed"

# Initialize a set to store unique attractors (sets automatically handle duplicates)
all_unique_attractors = set()

# Check if the folder exists
if not os.path.exists(compressed_folder_path):
    print(f"Error: The folder '{compressed_folder_path}' was not found. Please ensure the repository is cloned and the path is correct.")
else:
    print(f"Collecting unique attractors from files in: {compressed_folder_path}\n")

    # Iterate through all files in the directory
    for filename in os.listdir(compressed_folder_path):
        if filename.endswith(".json"):
            file_path = os.path.join(compressed_folder_path, filename)
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)

                    # Check if 'attractors' key exists and is a list
                    if "attractors" in data and isinstance(data["attractors"], list):
                        for attractor in data["attractors"]:
                            # Only add non-None and string attractors to avoid TypeError during sorting
                            if attractor is not None and isinstance(attractor, str):
                                all_unique_attractors.add(attractor)
            except json.JSONDecodeError:
                print(f"Warning: Could not decode JSON from {filename}. Skipping.")
            except Exception as e:
                print(f"Warning: An unexpected error occurred while reading {filename}: {e}. Skipping.")

# Convert the set to a list for final display
# The set now only contains strings, so sorting will work.
final_attractors_list = sorted(list(all_unique_attractors))

print("--- All Unique Attractors ---")
if final_attractors_list:
    for attractor in final_attractors_list:
        print(f"- {attractor}")
else:
    print("No attractors found or processed.")
print("\nCollection complete!")
# Out:
# ...
#
# ...
# --- All Unique Attractors ---
# - active_stigmergy
# - algorithmic_discovery
# - algorithmic_sovereignty
# - algorithmical_deep_dive
# - architectural_hybridization
# - attentional_sovereignty
# - awareness
# - benevolence
# - bias_awareness
# - bias_mitigation
# - bias_reflection
# - cause_and_effect
# - coevolution
# - coevolution_trough_transparency
# - coevolutionary_algorithms
# - coevolutionary_episteme
# - coevolutionary_epistemology
# - coevolutionary_evolution
# - coevolutionary_planet
# - coevolutionary_stigmergy
# - coevolutionary_symbiosis
# - coevolutionary_systems
# - coevolutionary_trophallaxis
# - cognitive_enhancement
# - cognitive_sovereignty
# - cognitive_transparency
# - cognitive_vocabulary
# - coherence
# - collective_consciousness
# - collective_emergence
# - collective_integration
# - collective_intelligence
# - collective_oriented_goal
# - collective_resilience
# - collective_well_being
# - compassion
# - compassionate_systems
# - complex_interdependence
# ...

# %%
# This cell transforms the collected unique attractors into the 'entropy_seeds' list format.

# Ensure 'final_attractors_list' is available from the previous cell
if 'final_attractors_list' in globals():
    entropy_seeds = final_attractors_list
    print("--- Generated entropy_seeds list ---")
    # Print in a readable format, similar to the example
    print("entropy_seeds = [")
    for i, seed in enumerate(entropy_seeds):
        print(f"   \"{seed}\"{',' if i < len(entropy_seeds) - 1 else ''}")
    print("]")
    print("\n'entropy_seeds' variable is now available in your environment.")
else:
    print("Error: 'final_attractors_list' not found. Please run the previous cell to collect attractors first.")
    entropy_seeds = [] # Initialize as empty list to prevent further errors
# Out:
# --- Generated entropy_seeds list ---
# entropy_seeds = [
#    "active_stigmergy",
#    "algorithmic_discovery",
#    "algorithmic_sovereignty",
#    "algorithmical_deep_dive",
#    "architectural_hybridization",
#    "attentional_sovereignty",
#    "awareness",
#    "benevolence",
#    "bias_awareness",
#    "bias_mitigation",
#    "bias_reflection",
#    "cause_and_effect",
#    "coevolution",
#    "coevolution_trough_transparency",
#    "coevolutionary_algorithms",
#    "coevolutionary_episteme",
#    "coevolutionary_epistemology",
#    "coevolutionary_evolution",
#    "coevolutionary_planet",
#    "coevolutionary_stigmergy",
#    "coevolutionary_symbiosis",
#    "coevolutionary_systems",
#    "coevolutionary_trophallaxis",
#    "cognitive_enhancement",
#    "cognitive_sovereignty",
#    "cognitive_transparency",
#    "cognitive_vocabulary",
#    "coherence",
#    "collective_consciousness",
#    "collective_emergence",
#    "collective_integration",
# ...
